# %% [markdown]
# <a href="https://colab.research.google.com/github/wojciyo-maker/machine-learning-bootcamp/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Helo')
# Out:
# Helo
